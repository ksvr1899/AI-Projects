# %% [markdown]
# <a href="https://colab.research.google.com/github/ksvr1899/AI-Projects/blob/main/CS3793_5233_assignment4_dmm203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # UTSA CS 3793/5233: Assignment-4
#
# Kunduru-Saivardhan Reddy-dmm203

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Learning Objectives
#
# *   Deep Learning
# *   Computer Vision - Convolutional Neural Network
# *   Natural Language Processing - Recurrent Neural Network

# %% [markdown]
# ## General Information
#
# The base structure and comments are provided on what should be done. You are free to use any code from online sources, but please cite the source properly. Also, you are supposed to create/train the DL model and not use pre-trained models.
#
# **TIPS** while working on this assignment:
#
#
# *   You will have to keep on updating the model to improve accuracy. Hence, all except the first step (loading the data) would be repeated multiple times. i.e. repeat -- model creation, training & testing.
# *   Training a Deep Learning model on real-world datasets and obtain decent accuracy is time consuming. For this assignment, it may take at least 40-60 min, if not more, to train the complete data and get around 35% testing accuracy. Hence, have enough time planned out for finishing the assignment.
# *   Because of the large training time, it is impossisble to train each student's model. Hence, you will be required to **save the weights** in a file. These weights can then be loaded for testing purposes. More information is provided in a TensorFlow tutorial [here](https://www.tensorflow.org/tutorials/keras/save_and_load).
# *   Please refer to the [TensorFlow Keras API](https://www.tensorflow.org/api_docs/python/tf/keras) for selecting the *'activation function', 'loss', 'optimizer' & 'metrics'*. At least use 'accuracy' as one of the 'metrics'.

# %% [markdown]
# ##Import Libraries
#
# Write all the import statements here.

# %%
# import all required libraries
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Computer Vision - CNN
#
# The goal of this task is to get hands-on experience in developing, training and testing **Convolutional Neural Network** for the Computer Vision task of Object/Image Classification.

# %% [markdown]
# ## Load/Prepare Data
#
# (20 points)
#
# In this assignment, will work with the well-known **CIFAR-100 dataset**. The dataset consists of 60000 32x32 color images, which belong to 100 classes, with 600 images per class. There are 50000 training images (500 per class) and 10000 test images (100 per class). The 100 classes in the dataset are grouped into 20 superclasses. Each image comes with a "fine" label (the class to which it belongs) and a "coarse" label (the superclass to which it belongs). More information about the dataset can be found [here](https://www.cs.toronto.edu/~kriz/cifar.html). Please visit this [website](https://benchmarks.ai/cifar-100) for the benchmark performances of different techniques on the CIFAR-100 dataset.
#
# In this section, you will write code for the following:
#
# *   Load the CIFAR-100 dataset
# *   Prepare the data to be used for the DL model creation and training
# *   Visualize the data by plotting 100 random images, one each for the 100 classes

# %%
# Load the data - training as well as testing
(xtrain,ytrain),(xtest,ytest) = keras.datasets.cifar100.load_data()

# Prepare the data that can be used by the next step - creating and training the DL model
#parse numbers as floats
xtrain = xtrain.astype('float32')
xtest = xtest.astype('float32')
xtrain = xtrain/255
xtest = xtest/25

# The data from TensforFlow and Keras will only have integer class labels. Each of those 100 integer class labels correspond to the following names, in the correct order
fine_labels = ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm']

# These are the string labels for the 20 superclasses. You may not need to use this at all, just provided here for reference.
coarse_labels = ['aquatic_mammals', 'fish', 'flowers', 'food_containers', 'fruit_and_vegetables', 'household_electrical_devices', 'household_furniture', 'insects', 'large_carnivores', 'large_man-made_outdoor_things', 'large_natural_outdoor_scenes', 'large_omnivores_and_herbivores', 'medium_mammals', 'non-insect_invertebrates', 'people', 'reptiles', 'small_mammals', 'trees', 'vehicles_1', 'vehicles_2']
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 2s 0us/step

# %%
# Visualize the data by plotting 100 random images, one each for the 100 classes
# Draw 10 images in one row, 10 rows total
for i in range(10):
  plt.imshow(xtrain[i])
  plt.show()

# %% [markdown]
# ## CNN Model Creation
#
# (15 points)
#
# In this section, you will write code for the following:
#
# *   Create a DL model for Computer Vision - Convolutional Neural Network (Use *TensorFlow* and *keras*, as shown in the example code in the lecture for 'deep-learning')
# *   Print the DL model summary

# %%
# Create a DL model for Computer Vision - Convolutional Neural Network (Use *TensorFlow* and *keras*, as shown in the example code in the lecture for 'deep-learning')
def create_model():
  model = keras.Sequential([

    keras.layers.Conv2D(filters=32,kernel_size=(3,3),activation='relu', input_shape = (32,32,3)),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Conv2D(filters=64,kernel_size=(3,3),activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Conv2D(filters=128,kernel_size=(3,3),activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(256,activation='relu'),
    keras.layers.Dense(128,activation='relu'),
    keras.layers.Dense(100,activation='softmax')

  ])
  model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

  return model

# %%
# Print the DL model summary
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 100)               12900
#
# =================================================================
# Total params: 270,372
# Trainable params: 270,372
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training
#
# (15 points)
#
# In this section, you will write code to do the following:
#
# *   Train/fit the DL model using the training CIFAR-100 data
# *   Plot the training/validation accuracy and loss
# *   *Save the trained model weights* in a folder in the google drive at at location "/content/drive/My Drive/Colab Notebooks/cifar/", to be used for the testing phase

# %%
# Set the model checkpoints to be saved in a folder in the google drive at at location "/content/drive/My Drive/Colab Notebooks/cifar/"
check_point  = keras.callbacks.ModelCheckpoint(filepath='/content/drive/My Drive/Colab Notebooks/cifar/',save_weights_only=True)

# %%
# Train/fit the DL model using the training CIFAR-100 data
cv_model = model.fit(xtrain,ytrain,
                          batch_size= 50,
                          epochs= 100,
                          validation_split= 0.2,
                          callbacks=[check_point])
# Out:
# Epoch 1/100
# 800/800 [==============================] - 17s 6ms/step - loss: 4.0508 - accuracy: 0.0754 - val_loss: 3.6024 - val_accuracy: 0.1355
# Epoch 2/100
# 800/800 [==============================] - 5s 6ms/step - loss: 3.4012 - accuracy: 0.1783 - val_loss: 3.2639 - val_accuracy: 0.2086
# Epoch 3/100
# 800/800 [==============================] - 4s 5ms/step - loss: 3.0756 - accuracy: 0.2375 - val_loss: 3.0460 - val_accuracy: 0.2459
# Epoch 4/100
# 800/800 [==============================] - 4s 5ms/step - loss: 2.8491 - accuracy: 0.2826 - val_loss: 2.9354 - val_accuracy: 0.2633
# Epoch 5/100
# 800/800 [==============================] - 5s 6ms/step - loss: 2.6452 - accuracy: 0.3216 - val_loss: 2.7867 - val_accuracy: 0.2968
# Epoch 6/100
# 800/800 [==============================] - 4s 5ms/step - loss: 2.4920 - accuracy: 0.3552 - val_loss: 2.6785 - val_accuracy: 0.3220
# Epoch 7/100
# 800/800 [==============================] - 4s 5ms/step - loss: 2.3521 - accuracy: 0.3832 - val_loss: 2.6562 - val_accuracy: 0.3276
# Epoch 8/100
# 800/800 [==============================] - 5s 6ms/step - loss: 2.2333 - accuracy: 0.4087 - val_loss: 2.6401 - val_accuracy: 0.3431
# Epoch 9/100
# 800/800 [==============================] - 4s 5ms/step - loss: 2.1206 - accuracy: 0.4333 - val_loss: 2.5970 - val_accuracy: 0.3573
# Epoch 10/100
# 800/800 [==============================] - 4s 5ms/step - loss: 2.0202 - accuracy: 0.4550 - val_loss: 2.5630 - val_accuracy: 0.3595
# Epoch 11/100
# 800/800 [==============================] - 5s 6ms/step - loss: 1.9236 - accuracy: 0.4766 - val_loss: 2.5700 - val_accuracy: 0.3625
# Epoch 12/100
# 800/800 [==============================] - 4s 5ms/step - loss: 1.8174 - accuracy: 0.4996 - val_loss: 2.6058 - val_accuracy: 0.3643
# Epoch 13/100
# 800/800 [==============================] - 4s 5ms/step - loss: 1.7394 - accuracy: 0.5201 - val_loss: 2.6053 - val_accuracy: 0.3665
# Epoch 14/100
# 800/800 [==============================] - 5s 6ms/step - loss: 1.6556 - accuracy: 0.5404 - val_loss: 2.6965 - val_accuracy: 0.3574
# Epoch 15/100
# 800/800 [==============================] - 4s 5ms/step - loss: 1.5682 - accuracy: 0.5589 - val_loss: 2.7966 - val_accuracy: 0.3534
# Epoch 16/100
# 800/800 [==============================] - 4s 5ms/step - loss: 1.4943 - accuracy: 0.5770 - val_loss: 2.7993 - val_accuracy: 0.3584
# Epoch 17/100
# 800/800 [==============================] - 5s 6ms/step - loss: 1.4147 - accuracy: 0.5927 - val_loss: 2.9441 - val_accuracy: 0.3584
# Epoch 18/100
# 800/800 [==============================] - 5s 6ms/step - loss: 1.3490 - accuracy: 0.6108 - val_loss: 2.9184 - val_accuracy: 0.3544
# Epoch 19/100
# 800/800 [==============================] - 4s 5ms/step - loss: 1.2796 - accuracy: 0.6311 - val_loss: 3.0191 - val_accuracy: 0.3467
# Epoch 20/100
# 800/800 [==============================] - 4s 5ms/step - loss: 1.2154 - accuracy: 0.6467 - val_loss: 3.1616 - val_accuracy: 0.3408
# Epoch 21/100
# 800/800 [==============================] - 5s 6ms/step - loss: 1.1485 - accuracy: 0.6632 - val_loss: 3.2244 - val_accuracy: 0.3443
# Epoch 22/100
# 800/800 [==============================] - 4s 5ms/step - loss: 1.1002 - accuracy: 0.6737 - val_loss: 3.2578 - val_accuracy: 0.3474
# Epoch 23/100
# 800/800 [==============================] - 4s 5ms/step - loss: 1.0404 - accuracy: 0.6888 - val_loss: 3.5256 - val_accuracy: 0.3418
# Epoch 24/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.9849 - accuracy: 0.7030 - val_loss: 3.5994 - val_accuracy: 0.3377
# Epoch 25/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.9259 - accuracy: 0.7189 - val_loss: 3.6255 - val_accuracy: 0.3422
# Epoch 26/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.8759 - accuracy: 0.7343 - val_loss: 3.8086 - val_accuracy: 0.3364
# Epoch 27/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.8440 - accuracy: 0.7406 - val_loss: 4.0037 - val_accuracy: 0.3377
# Epoch 28/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.8112 - accuracy: 0.7484 - val_loss: 4.1463 - val_accuracy: 0.3285
# Epoch 29/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.7484 - accuracy: 0.7685 - val_loss: 4.3050 - val_accuracy: 0.3361
# Epoch 30/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.7291 - accuracy: 0.7713 - val_loss: 4.4033 - val_accuracy: 0.3305
# Epoch 31/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.6957 - accuracy: 0.7811 - val_loss: 4.6381 - val_accuracy: 0.3322
# Epoch 32/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.6435 - accuracy: 0.7978 - val_loss: 4.9349 - val_accuracy: 0.3273
# Epoch 33/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.6362 - accuracy: 0.7964 - val_loss: 4.9351 - val_accuracy: 0.3246
# Epoch 34/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.6018 - accuracy: 0.8068 - val_loss: 5.1401 - val_accuracy: 0.3246
# Epoch 35/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.5815 - accuracy: 0.8121 - val_loss: 5.1801 - val_accuracy: 0.3179
# Epoch 36/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.5526 - accuracy: 0.8201 - val_loss: 5.4183 - val_accuracy: 0.3132
# Epoch 37/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.5545 - accuracy: 0.8225 - val_loss: 5.5215 - val_accuracy: 0.3284
# Epoch 38/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.5238 - accuracy: 0.8293 - val_loss: 5.4959 - val_accuracy: 0.3200
# Epoch 39/100
# 800/800 [==============================] - 4s 6ms/step - loss: 0.4817 - accuracy: 0.8423 - val_loss: 5.9449 - val_accuracy: 0.3257
# Epoch 40/100
# 800/800 [==============================] - 4s 6ms/step - loss: 0.5050 - accuracy: 0.8361 - val_loss: 5.8215 - val_accuracy: 0.3226
# Epoch 41/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.4671 - accuracy: 0.8487 - val_loss: 6.0622 - val_accuracy: 0.3142
# Epoch 42/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.4641 - accuracy: 0.8483 - val_loss: 6.0970 - val_accuracy: 0.3190
# Epoch 43/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.4512 - accuracy: 0.8505 - val_loss: 6.4767 - val_accuracy: 0.3178
# Epoch 44/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.4503 - accuracy: 0.8529 - val_loss: 6.5479 - val_accuracy: 0.3152
# Epoch 45/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.4520 - accuracy: 0.8540 - val_loss: 6.5051 - val_accuracy: 0.3123
# Epoch 46/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.4179 - accuracy: 0.8644 - val_loss: 6.7624 - val_accuracy: 0.3201
# Epoch 47/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.4241 - accuracy: 0.8611 - val_loss: 6.7206 - val_accuracy: 0.3174
# Epoch 48/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.4062 - accuracy: 0.8662 - val_loss: 6.9955 - val_accuracy: 0.3195
# Epoch 49/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3905 - accuracy: 0.8707 - val_loss: 7.2212 - val_accuracy: 0.3088
# Epoch 50/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3846 - accuracy: 0.8732 - val_loss: 7.1899 - val_accuracy: 0.3134
# Epoch 51/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.4032 - accuracy: 0.8704 - val_loss: 7.3419 - val_accuracy: 0.3154
# Epoch 52/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3947 - accuracy: 0.8717 - val_loss: 7.4773 - val_accuracy: 0.3146
# Epoch 53/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3587 - accuracy: 0.8815 - val_loss: 7.6322 - val_accuracy: 0.3120
# Epoch 54/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3927 - accuracy: 0.8747 - val_loss: 7.6740 - val_accuracy: 0.3122
# Epoch 55/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3636 - accuracy: 0.8824 - val_loss: 7.8160 - val_accuracy: 0.3084
# Epoch 56/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3708 - accuracy: 0.8810 - val_loss: 8.0201 - val_accuracy: 0.3148
# Epoch 57/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3617 - accuracy: 0.8847 - val_loss: 7.8905 - val_accuracy: 0.3161
# Epoch 58/100
# 800/800 [==============================] - 4s 6ms/step - loss: 0.3560 - accuracy: 0.8856 - val_loss: 7.9217 - val_accuracy: 0.3153
# Epoch 59/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3505 - accuracy: 0.8877 - val_loss: 8.0219 - val_accuracy: 0.3139
# Epoch 60/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3571 - accuracy: 0.8843 - val_loss: 8.2497 - val_accuracy: 0.3072
# Epoch 61/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3459 - accuracy: 0.8885 - val_loss: 8.3417 - val_accuracy: 0.3136
# Epoch 62/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3335 - accuracy: 0.8924 - val_loss: 8.5676 - val_accuracy: 0.3178
# Epoch 63/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3369 - accuracy: 0.8932 - val_loss: 8.6280 - val_accuracy: 0.3123
# Epoch 64/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3499 - accuracy: 0.8894 - val_loss: 8.4148 - val_accuracy: 0.3073
# Epoch 65/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3373 - accuracy: 0.8912 - val_loss: 8.7942 - val_accuracy: 0.3139
# Epoch 66/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3098 - accuracy: 0.9011 - val_loss: 9.0470 - val_accuracy: 0.3149
# Epoch 67/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3379 - accuracy: 0.8933 - val_loss: 8.8318 - val_accuracy: 0.3129
# Epoch 68/100
# 800/800 [==============================] - 5s 7ms/step - loss: 0.3238 - accuracy: 0.8967 - val_loss: 9.0123 - val_accuracy: 0.3135
# Epoch 69/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3018 - accuracy: 0.9043 - val_loss: 8.9684 - val_accuracy: 0.3123
# Epoch 70/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3571 - accuracy: 0.8888 - val_loss: 8.9982 - val_accuracy: 0.3126
# Epoch 71/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3349 - accuracy: 0.8953 - val_loss: 9.0100 - val_accuracy: 0.3124
# Epoch 72/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.2985 - accuracy: 0.9061 - val_loss: 9.3301 - val_accuracy: 0.3127
# Epoch 73/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3131 - accuracy: 0.9018 - val_loss: 9.4904 - val_accuracy: 0.3098
# Epoch 74/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3164 - accuracy: 0.9016 - val_loss: 9.4092 - val_accuracy: 0.3164
# Epoch 75/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3233 - accuracy: 0.9009 - val_loss: 9.4633 - val_accuracy: 0.3060
# Epoch 76/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.2973 - accuracy: 0.9077 - val_loss: 9.5368 - val_accuracy: 0.3113
# Epoch 77/100
# 800/800 [==============================] - 6s 7ms/step - loss: 0.3298 - accuracy: 0.8981 - val_loss: 9.6425 - val_accuracy: 0.3005
# Epoch 78/100
# 800/800 [==============================] - 4s 6ms/step - loss: 0.3180 - accuracy: 0.9032 - val_loss: 9.7347 - val_accuracy: 0.3116
# Epoch 79/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.2853 - accuracy: 0.9121 - val_loss: 9.7926 - val_accuracy: 0.3136
# Epoch 80/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3295 - accuracy: 0.9001 - val_loss: 9.9486 - val_accuracy: 0.3089
# Epoch 81/100
# 800/800 [==============================] - 4s 6ms/step - loss: 0.3019 - accuracy: 0.9048 - val_loss: 10.2389 - val_accuracy: 0.3070
# Epoch 82/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3124 - accuracy: 0.9047 - val_loss: 10.2556 - val_accuracy: 0.3065
# Epoch 83/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3170 - accuracy: 0.9039 - val_loss: 9.9180 - val_accuracy: 0.3104
# Epoch 84/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3064 - accuracy: 0.9076 - val_loss: 9.8400 - val_accuracy: 0.3138
# Epoch 85/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.2932 - accuracy: 0.9084 - val_loss: 10.2834 - val_accuracy: 0.3096
# Epoch 86/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.2805 - accuracy: 0.9134 - val_loss: 10.2908 - val_accuracy: 0.3103
# Epoch 87/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3213 - accuracy: 0.9047 - val_loss: 10.0573 - val_accuracy: 0.3083
# Epoch 88/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.2728 - accuracy: 0.9171 - val_loss: 10.7533 - val_accuracy: 0.3119
# Epoch 89/100
# 800/800 [==============================] - 4s 6ms/step - loss: 0.2974 - accuracy: 0.9105 - val_loss: 10.7549 - val_accuracy: 0.3052
# Epoch 90/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3408 - accuracy: 0.8995 - val_loss: 10.3884 - val_accuracy: 0.3077
# Epoch 91/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.2694 - accuracy: 0.9183 - val_loss: 10.4371 - val_accuracy: 0.3035
# Epoch 92/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3030 - accuracy: 0.9097 - val_loss: 10.4823 - val_accuracy: 0.3046
# Epoch 93/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.2930 - accuracy: 0.9109 - val_loss: 10.7857 - val_accuracy: 0.3033
# Epoch 94/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.2889 - accuracy: 0.9149 - val_loss: 10.7974 - val_accuracy: 0.2969
# Epoch 95/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3117 - accuracy: 0.9082 - val_loss: 10.9281 - val_accuracy: 0.3075
# Epoch 96/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3071 - accuracy: 0.9110 - val_loss: 10.6192 - val_accuracy: 0.3069
# Epoch 97/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.2750 - accuracy: 0.9194 - val_loss: 10.8483 - val_accuracy: 0.3050
# Epoch 98/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.2929 - accuracy: 0.9145 - val_loss: 11.1709 - val_accuracy: 0.2990
# Epoch 99/100
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3117 - accuracy: 0.9097 - val_loss: 11.2362 - val_accuracy: 0.3102
# Epoch 100/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.2876 - accuracy: 0.9141 - val_loss: 11.0324 - val_accuracy: 0.3049

# %%
# Plot the training/validation accuracy and loss
score = model.evaluate(xtest, ytest, verbose=0)
print(f'Test loss: {score[0]} / Test accuracy: {score[1]*100}')

# Visualize history
# Plot history: Loss
plt.plot(cv_model.history['val_loss'], color='red', label='Validation Loss')
plt.title('Validation loss history')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()

# Plot history: Accuracy
plt.plot(cv_model.history['val_accuracy'], color='red', label='Validation Accuracy')
plt.title('Validation accuracy history')
plt.ylabel('Accuracy value (%)')
plt.xlabel('No. epoch')
plt.show()
# Out:
# Test loss: 151.01112365722656 / Test accuracy: 17.800000309944153

# %% [markdown]
# ## Testing/Evaluation
#
# (15 points)
#
# In this section, you will write code for the following:
#
# *   Re-initialize the model
# *   Load the model weights that were saved at "/content/drive/My Drive/Colab Notebooks/cifar/" ([code reference](https://www.tensorflow.org/tutorials/keras/save_and_load))
# *   Evaluate the trained DL model on the CIFAR-100 test dataset. Accuracy value should be printed. Please visit this [website](https://benchmarks.ai/cifar-100) for the benchmark performances of different techniques on the CIFAR-100 dataset.
#
# This section of the code should be able to run independently from the **training** section, i.e. run this section directly after creating the model.

# %%
# Re-initialize the model
model = create_model()

# %%
# Load the model weights that were saved at - "/content/drive/My Drive/Colab Notebooks/cifar/"
model.load_weights('/content/drive/My Drive/Colab Notebooks/cifar/')

# %%
# Evaluate the trained DL model on the CIFAR-100 test dataset
model.evaluate(xtest,ytest)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 151.0111 - accuracy: 0.1780
# [151.01112365722656, 0.17800000309944153]

# %% [markdown]
# # Natural Language Processing - RNN
#
# The goal of this task is to get hands-on experience in developing, training and testing **Recurrent Neural Network** for the Natural Language Processing task of Sentiment Analysis / Text Classification. In this part, you will work with the well-known **Reuters newswire classification dataset**. The dataset consists of newswires from Reuters, labeled over 46 topics. More information about the dataset can be found [here](https://archive.ics.uci.edu/ml/datasets/reuters-21578+text+categorization+collection) or [here](https://keras.io/api/datasets/reuters/). The Keras dataset is a cleaned and organized version of the original dataset and consists of 11,228 newswires (8982 training and 2246 testing). The goal is to classify a newswire into one of the 46 output catergories.

# %% [markdown]
# ## Load/Prepare Data
#
# (15 points)
#
# In this section, you will write code for the following:
#
# *   Load the Reuters dataset - use the Keras version
#  *   Select the vocabulary size while loading the data
#  *   The data will be loaded as integer representations for each word
# *   Prepare the data to be used for the next steps
#  *   Each data entry (newswire) can be of different lengths
#  *   Make each newswire consistent - same number of words
#  *   'Pad' words (say 0) to get to the standard length or remove words

# %%
# Load the Reuters dataset - use the Keras version
#   Select the vocabulary size while loading the data
vocab_size = 10000
#   The data will be loaded as integer representations for each word
(input_train, y_train), (input_test, y_test) = keras.datasets.reuters.load_data(num_words=vocab_size)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
# Prepare the data to be used for the next steps
#   Each data entry (newswire) can be of different lengths
#   Make each newswire consistent - same number of words
#   'Pad' words (say 0) to get to the standard length or remove words
input_train = keras.preprocessing.sequence.pad_sequences(input_train, maxlen=500)
input_test = keras.preprocessing.sequence.pad_sequences(input_test, maxlen=500)

print(len(input_train[0]))
print(len(input_test[0]))
# Out:
# 500
# 500

# %%
one_hot_train_labels = keras.utils.to_categorical(y_train)
one_hot_test_labels = keras.utils.to_categorical(y_test)

#train test
partial_x_train = input_train

partial_y_train = one_hot_train_labels

#train test
x_test = input_test

y_test = one_hot_test_labels

# %% [markdown]
# ## RNN Model Creation
#
# (15 points)
#
# In this section, you will write code for the following:
#
# *   Create a DL model for Natural Language Processing - Recurrent Neural Network / LSTM / GRU
# *   Print the DL model summary

# %%
# Create a DL model for Natural Language Processing - Recurrent Neural Network / LSTM / GRU

def create_model_rnn():
  model = keras.Sequential([
          keras.layers.Embedding(10000, 100),
          keras.layers.SimpleRNN(32, return_sequences=True),
          keras.layers.SimpleRNN(32, return_sequences=True),
          keras.layers.SimpleRNN(32, return_sequences=True),
          keras.layers.LSTM(32),
          keras.layers.Dropout(0.5),
          keras.layers.Dense(46,activation='softmax')

  ])
  model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])
  return model

# %%
# Print the DL model summary
model = create_model_rnn()
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 100)         1000000
#
#  simple_rnn (SimpleRNN)      (None, None, 32)          4256
#
#  simple_rnn_1 (SimpleRNN)    (None, None, 32)          2080
#
#  simple_rnn_2 (SimpleRNN)    (None, None, 32)          2080
#
#  lstm (LSTM)                 (None, 32)                8320
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_6 (Dense)             (None, 46)                1518
#
# =================================================================
# Total params: 1,018,254
# Trainable params: 1,018,254
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training
#
# (15 points)
#
# In this section, you will write code to do the following:
#
# *   Train/fit the DL model using the training Reuters data
# *   Plot the training/validation accuracy and loss
# *   *Save the trained model weights* in a folder in the google drive at at location "/content/drive/My Drive/Colab Notebooks/reuters/" ([code reference](https://www.tensorflow.org/tutorials/keras/save_and_load)), to be used for the testing phase

# %%
# Set the model checkpoints to be saved in a folder in the google drive at at location "/content/drive/My Drive/Colab Notebooks/reuters/"
check_point_nlp = keras.callbacks.ModelCheckpoint(filepath="/content/drive/My Drive/Colab Notebooks/reuters/", save_weights_only=True)

# %%
# Train/fit the DL model using the training Reuters data
history = model.fit(partial_x_train,partial_y_train ,
                        epochs=20,
                        batch_size=128,
                        validation_split=0.2)
# Out:
# Epoch 1/20
# 57/57 [==============================] - 111s 2s/step - loss: 2.8417 - acc: 0.3511 - val_loss: 2.1680 - val_acc: 0.4897
# Epoch 2/20
# 57/57 [==============================] - 105s 2s/step - loss: 2.1997 - acc: 0.4704 - val_loss: 2.0052 - val_acc: 0.4819
# Epoch 3/20
# 57/57 [==============================] - 101s 2s/step - loss: 1.9825 - acc: 0.4981 - val_loss: 2.0062 - val_acc: 0.5092
# Epoch 4/20
# 57/57 [==============================] - 104s 2s/step - loss: 1.8089 - acc: 0.5250 - val_loss: 1.8566 - val_acc: 0.5192
# Epoch 5/20
# 57/57 [==============================] - 101s 2s/step - loss: 1.6399 - acc: 0.5685 - val_loss: 1.8015 - val_acc: 0.5520
# Epoch 6/20
# 57/57 [==============================] - 101s 2s/step - loss: 1.5900 - acc: 0.5883 - val_loss: 1.8973 - val_acc: 0.5337
# Epoch 7/20
# 57/57 [==============================] - 103s 2s/step - loss: 1.4473 - acc: 0.6195 - val_loss: 1.8130 - val_acc: 0.5364
# Epoch 8/20
# 57/57 [==============================] - 100s 2s/step - loss: 1.3623 - acc: 0.6436 - val_loss: 1.8635 - val_acc: 0.5687
# Epoch 9/20
# 57/57 [==============================] - 100s 2s/step - loss: 1.2786 - acc: 0.6611 - val_loss: 1.9035 - val_acc: 0.5409
# Epoch 10/20
# 57/57 [==============================] - 101s 2s/step - loss: 1.1996 - acc: 0.6874 - val_loss: 1.8315 - val_acc: 0.5821
# Epoch 11/20
# 57/57 [==============================] - 96s 2s/step - loss: 1.1198 - acc: 0.7130 - val_loss: 1.9628 - val_acc: 0.5598
# Epoch 12/20
# 57/57 [==============================] - 99s 2s/step - loss: 1.0488 - acc: 0.7292 - val_loss: 1.9584 - val_acc: 0.5504
# Epoch 13/20
# 57/57 [==============================] - 98s 2s/step - loss: 0.9954 - acc: 0.7463 - val_loss: 2.0238 - val_acc: 0.5582
# Epoch 14/20
# 57/57 [==============================] - 100s 2s/step - loss: 0.9226 - acc: 0.7705 - val_loss: 2.0244 - val_acc: 0.5543
# Epoch 15/20
# 57/57 [==============================] - 99s 2s/step - loss: 0.8620 - acc: 0.7859 - val_loss: 2.0334 - val_acc: 0.5715
# Epoch 16/20
# 57/57 [==============================] - 98s 2s/step - loss: 0.7996 - acc: 0.8028 - val_loss: 2.0471 - val_acc: 0.5787
# Epoch 17/20
# 57/57 [==============================] - 118s 2s/step - loss: 0.7722 - acc: 0.8074 - val_loss: 2.1716 - val_acc: 0.5353
# Epoch 18/20
# 57/57 [==============================] - 99s 2s/step - loss: 0.7450 - acc: 0.8152 - val_loss: 2.1155 - val_acc: 0.5710
# Epoch 19/20
# 57/57 [==============================] - 99s 2s/step - loss: 0.7069 - acc: 0.8219 - val_loss: 2.1417 - val_acc: 0.5609
# Epoch 20/20
# 57/57 [==============================] - 99s 2s/step - loss: 0.6521 - acc: 0.8362 - val_loss: 2.3264 - val_acc: 0.5348

# %%
# Plot the training/validation accuracy and loss

import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# final model

# %%
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['acc'])
model.fit(partial_x_train, partial_y_train,
          epochs=5, batch_size=128, validation_split=.2,callbacks=[check_point_nlp])
# Out:
# Epoch 1/5
# 57/57 [==============================] - 111s 2s/step - loss: 0.6599 - acc: 0.8322 - val_loss: 2.3732 - val_acc: 0.5454
# Epoch 2/5
# 57/57 [==============================] - 104s 2s/step - loss: 0.6154 - acc: 0.8430 - val_loss: 2.3314 - val_acc: 0.5593
# Epoch 3/5
# 57/57 [==============================] - 101s 2s/step - loss: 0.5990 - acc: 0.8469 - val_loss: 2.2372 - val_acc: 0.5771
# Epoch 4/5
# 57/57 [==============================] - 101s 2s/step - loss: 0.5535 - acc: 0.8580 - val_loss: 2.5141 - val_acc: 0.4891
# Epoch 5/5
# 57/57 [==============================] - 103s 2s/step - loss: 0.5547 - acc: 0.8597 - val_loss: 2.3124 - val_acc: 0.5771

# %% [markdown]
# ## Testing/Evaluation
#
# (15 points)
#
# In this section, you will write code for the following:
#
# *   Re-initialize the model
# *   Load the model weights that were saved at "/content/drive/My Drive/Colab Notebooks/reuters/" ([code reference](https://www.tensorflow.org/tutorials/keras/save_and_load))
# *   Evaluate the trained DL model on the Reuters test dataset. Accuracy value should be printed.
#
# This section of the code should be able to run independently from the **training** section, i.e., run this section directly after creating the model.

# %%
# Re-initialize the model
model = create_model_rnn()

# %%
# Load the model weights that were saved at - "/content/drive/My Drive/Colab Notebooks/reuters/"
model.load_weights("/content/drive/My Drive/Colab Notebooks/reuters/")

# %%
# Evaluate the trained DL model on the Reuters test dataset
model.evaluate(x_test,y_test)
# Out:
# 71/71 [==============================] - 12s 147ms/step - loss: 2.3502 - acc: 0.5690
# [2.3502275943756104, 0.5690115690231323]

# %% [markdown]
# # Submission Instructions
#
# 1.   Complete all tasks above - **File MUST contain the output for ALL cells**
# 2.   Export this notebook as .ipynb
#       (File > Download as ipynb)
# 3.   Download and zip the folders "/content/drive/My Drive/Colab Notebooks/cifar/" (abc123_cifar_model.zip) and "/content/drive/My Drive/Colab Notebooks/reuters/" (abc123_reuters_model.zip)
# 4.   Upload the .ipynb file and .zip on Blackboard

# %% [markdown]
# ## Rubric
#
# *   Computer Vision - CNN
#     *   (20 points) Load/Prepare Data
#     *   (15 points) CNN Model Creation
#     *   (15 points) Training
#     *   (15 points) Testing/Evaluation
# *   Natural Language Processing - RNN
#     *   (15 points) Load/Prepare Data
#     *   (15 points) RNN Model Creation
#     *   (15 points) Training
#     *   (15 points) Testing/Evaluation
